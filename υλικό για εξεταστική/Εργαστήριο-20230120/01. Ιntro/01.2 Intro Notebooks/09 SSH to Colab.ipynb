# %% [markdown]
# # SSH - SFTP to Colab
#
# Θεωρούμε ότι έχετε openssh client.
#
# Εγκαταστήστε το [Cloudflared](https://developers.cloudflare.com/cloudflare-one/connections/connect-apps/install-and-setup/installation) για την πλατφόρμα σας. To Cloudflared θα μας δώσει τη δυνατότητα να κάνουμε ένα ssh tunnel
#
# ![Image of Yaktocat](https://octodex.github.com/images/yaktocat.png)
#
# Ακολουθήστε τις οδηγίες που θα βγάλει για το αρχείο config του directory .ssh. Αυτό χρειάζεται μόνο την πρώτη φορά.

# %%
  # !pip install colab_ssh --upgrade
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
# Install colab_ssh on google colab
# !pip install colab_ssh --upgrade

from colab_ssh import launch_ssh_cloudflared, init_git_cloudflared
launch_ssh_cloudflared(password="2pDiTbb6I3QW")
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# <style>
# *{
# 	outline:none;
# }
# code{
# 	display:inline-block;
# 	padding:5px 10px;
# 	background: #444;
# 	border-radius: 4px;
# 	white-space: pre-wrap;
# 	position:relative;
# 	color:white;
# }
# .copy-code-button{
# 	float:right;
# 	background:#333;
# 	color:white;
# 	border: none;
# 	margin: 0 0 0 10px;
# 	cursor: pointer;
# }
# p, li{
# 	max-width:700px;
# }
# .choices{
# 	display:flex;
# 	flex: 1 0 auto;
# }
# .choice-section{
# 	border:solid 1px #555;
# 	border-radius: 4px;
# 	min-width:300px;
# 	margin: 10px 15px 0 0;
# 	padding: 0 15px 15px 15px ;
# }
# .button{
# 	padding: 10px 15px;
# 	background:#333;
# 	border-radius: 4px;
# 	border:solid 1px #555;
# 	color:white;
# 	font-weight:bold;
# 	cursor:pointer;
# }
# .pill{
# 	padding:2px 4px;
# 	border-radius: 100px;
# 	background-color:#e65858;
# 	font-size:12px;
# 	font-weight:bold;
# 	margin: 0 15px;
# 	color:white;
# }
# ...

# %% [markdown]
# *   Ως root μπορείτε να εγκαταστήσετε ό,τι θέλετε (apt)
# *   Μπορούμε να κάνουμε tunnel και γραφικές εφαρμογές (X server forwarding). Αυτό θα φανεί χρήσιμο στο Deep Learning για το TensorBoard
# *   Το userspace των notebook είναι στο `/content`
#
#
#
# credits: [colab-ssh](https://github.com/WassimBenzarti/colab-ssh#getting-started)
